# %%
N = 500000
x = []
for i in range(N):
    x.append(random.uniform(0,1))
plt.hist(x, bins=30, density=1)
# Out:
# (array([0.9923413 , 1.00806132, 1.00728132, 1.00482131, 1.00968132,
#         1.00194131, 1.01022132, 1.00746132, 0.9972613 , 0.98262128,
#         0.9933613 , 0.98748129, 0.9922213 , 0.99072129, 0.9978013 ,
#         1.00176131, 1.00956132, 1.00014131, 0.9949213 , 1.01148132,
#         0.99072129, 1.00476131, 1.00596131, 1.00038131, 0.9912613 ,
#         0.9922813 , 1.00488131, 1.00452131, 1.00368131, 1.00044131]),
#  array([1.26602846e-06, 3.33345558e-02, 6.66678456e-02, 1.00001135e-01,
#         1.33334425e-01, 1.66667715e-01, 2.00001005e-01, 2.33334294e-01,
#         2.66667584e-01, 3.00000874e-01, 3.33334164e-01, 3.66667453e-01,
#         4.00000743e-01, 4.33334033e-01, 4.66667323e-01, 5.00000612e-01,
#         5.33333902e-01, 5.66667192e-01, 6.00000482e-01, 6.33333772e-01,
#         6.66667061e-01, 7.00000351e-01, 7.33333641e-01, 7.66666931e-01,
#         8.00000220e-01, 8.33333510e-01, 8.66666800e-01, 9.00000090e-01,
#         9.33333379e-01, 9.66666669e-01, 9.99999959e-01]),
# ...

# %%
import matplotlib.pyplot as plt
import random
