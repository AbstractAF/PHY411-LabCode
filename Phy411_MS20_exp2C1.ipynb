# %%
N = 500
x = []
for i in range(N):
    x.append(random.uniform(0,1))
plt.hist(x, bins=30, density=1)
# Out:
# (array([0.90147598, 0.84137758, 0.96157438, 0.84137758, 0.72118079,
#         0.72118079, 1.02167278, 1.38226317, 1.26206638, 1.02167278,
#         1.08177118, 1.50245997, 1.08177118, 0.78127919, 0.96157438,
#         1.32216477, 1.32216477, 0.72118079, 0.78127919, 1.14186958,
#         0.84137758, 0.90147598, 1.08177118, 1.14186958, 1.14186958,
#         0.90147598, 1.08177118, 0.90147598, 0.84137758, 0.84137758]),
#  array([0.00163647, 0.03491522, 0.06819398, 0.10147274, 0.13475149,
#         0.16803025, 0.20130901, 0.23458776, 0.26786652, 0.30114528,
#         0.33442403, 0.36770279, 0.40098155, 0.4342603 , 0.46753906,
#         0.50081782, 0.53409657, 0.56737533, 0.60065409, 0.63393284,
#         0.6672116 , 0.70049036, 0.73376912, 0.76704787, 0.80032663,
#         0.83360539, 0.86688414, 0.9001629 , 0.93344166, 0.96672041,
#         0.99999917]),
#  <BarContainer object of 30 artists>)

# %%
import matplotlib.pyplot as plt
import random
